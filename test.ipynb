# %%
from rdf_parser import parse

# %%
filename = "tests/exampleWithErrors.ttl"
# filename = "tests/example.ttl"
# filename = "tests/correctedSnippet1.ttl"

# %%
with open(filename) as f:
    rdf_txt = f.read()

rdf_txt
# Out:
# '@prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>.\n@prefix owl: <http://www.w3.org/2002/07/owl#>.\n@prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>.\n@prefix xsd: <http://www.w3.org/2001/XMLSchema#>.\n@prefix : <http://example.com/ontology#>.\n\n# Classes\n:Animal a owl:Class ;\n    rdfs:label "Animal" ;\n    rdfs:comment "Represents an animal in the ecosystem".\n\n:Plant a owl:Class ;\n    rdfs:label "Plant" ;\n    rdfs:comment "Represents a plant in the ecosystem".\n\n:Herbivore a owl:Class ;\n    rdfs:label "Herbivore" ;\n    rdfs:comment "Represents an animal that primarily eats plants";\n    rdfs:subClassOf :Animal ;\n    owl:equivalentClass [\n        a owl:Restriction ;\n        owl:onProperty :eats ;\n        owl:allValuesFrom :Plant\n    ].\n\n:Carnivore a owl:Class ;\n    rdfs:label "Carnivore" ;\n    rdfs:comment "Represents an animal that primarily eats other animals";\n    rdfs:subClassOf :Animal ;\n    owl:equivalentClass [\n        a owl:Restriction ;\n
# ...

# %%
parse_results = parse(rdf_txt)
g = parse_results.graph

print(len(g))
# prints: 2

import pprint
for stmt in g:
    pprint.pprint(stmt)
# Out:
# 82
# (rdflib.term.URIRef('http://example.com/ontology#isCarnivore'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('isCarnivore'))
# (rdflib.term.URIRef('http://example.com/ontology#Habitat'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.com/ontology#isHerbivore'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('Specifies if an animal is a herbivore'))
# (rdflib.term.BNode('ne696db6d1a05472b8df584357f75ecd8b1'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.w3.org/2002/07/owl#Class'))
# (rdflib.term.URIRef('http://example.com/ontology#isCarnivore'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#range'),
#  rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#boolean'))
# ...

# %%
errors = parse_results.block_errors

# %%
print(errors[2].block_txt)
# Out:
# @prefix rdf: <http://www.w3.org/1999/02/22-rdf-syntax-ns#>.
# @prefix owl: <http://www.w3.org/2002/07/owl#>.
# @prefix rdfs: <http://www.w3.org/2000/01/rdf-schema#>.
# @prefix xsd: <http://www.w3.org/2001/XMLSchema#>.
# @prefix : <http://example.com/ontology#>.
# # Disjointness Axioms
# owl:disjointClasses :Herbivore, :Carnivore, :Plant.
